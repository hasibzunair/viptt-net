# %% [markdown]
# # Trains a CNN-LSTM model on a subset of UCF_50 dataset.

# %%
# !nvidia-smi
# Out:
# Sun Apr 11 05:19:59 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
colab = True
if colab:
    # Mount drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    # Set path to working directory
    import sys
    sys.path.append('/content/gdrive/My Drive/tbt-classification/')
    # %cd /content/gdrive/My\ Drive/deeplearning/tbt-classification/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/deeplearning/tbt-classification

# %%
# !pip install -U --pre tensorflow=="2.2.0" -q

# %%
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }setInterval(ClickConnect,60000)

# %%
import tensorflow as tf
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, classification_report
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score


ROOT_DIR = os.path.abspath("./")
CFG_NAME = "vgg_lstm_10_sgd_tf24"
LOG_PATH = os.path.join(ROOT_DIR, "logs", CFG_NAME)

DATASET_PATH = os.path.join(ROOT_DIR, "dataset/UCF50_subset")

# Make logs directory, dump all experiment results inside this sub folder
if not os.path.exists(os.path.join(ROOT_DIR, "logs")):
    os.mkdir(os.path.join(ROOT_DIR, "logs"))

# Make new directory for the current experiment
if not os.path.exists(LOG_PATH):
    os.mkdir(LOG_PATH)


data_dir = DATASET_PATH
img_height , img_width = 224, 224
seq_len = 70

#classes = ["Basketball", "HighJump", "GolfSwing", "HorseRace", "Kayaking", "Skiing"]
classes = ['Mixing',
 'TennisSwing',
 'HorseRiding',
 'JumpRope',
 'JumpingJack',
 'BaseballPitch',
 'Rowing',
 'SkateBoarding',
 'WalkingWithDog',
 'Skijet']

num_classes = len(classes)

def compute_accuray_kappa_score(y1, y2):
    """Computes acc and kappa scores
    y1 : (N,) shape of labels
    y2 : (N,) shape of predicted labels
    """
    # Accuracy
    acc = accuracy_score(y1, y2) * 100
    print("Accuracy : {:.3f}".format(acc)) 

    # Kappa 
    # -1 to 1, 1 means complete agreement
    # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.cohen_kappa_score.html
    # https://stackoverflow.com/questions/43676905/how-to-calculate-cohens-kappa-coefficient-that-measures-inter-rater-agreement
    kappa = cohen_kappa_score(y1, y2)
    print("Kappa Score : {:.3f}".format(kappa))


def plot_loss_accu(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(loss))
    plt.plot(epochs, loss, 'g')
    plt.plot(epochs, val_loss, 'y')
    #plt.title('Training and validation loss')
    plt.ylabel('Loss %')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], loc='upper right')
    plt.grid(True)
    plt.savefig('{}/{}_loss.jpg'.format(LOG_PATH, CFG_NAME), dpi=100)
    plt.show()

    loss = history.history['accuracy']
    val_loss = history.history['val_accuracy']
    epochs = range(len(loss))
    plt.plot(epochs, loss, 'r')
    plt.plot(epochs, val_loss, 'b')
    #plt.title('Training and validation accuracy')
    plt.ylabel('Accuracy %')
    plt.xlabel('Epoch')
    plt.legend(['train', 'val'], loc='lower right')
    plt.grid(True)
    plt.savefig('{}/{}_acc.jpg'.format(LOG_PATH, CFG_NAME), dpi=100)
    plt.show()


def plot_slices(num_rows, num_columns, width, height, channels, video):
    """Plot a montage of slices"""
    data = video.copy()
    #data = np.rot90(np.array(data))
    #data = np.transpose(data)
    data = np.reshape(data, (num_rows, num_columns, width, height, channels))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    ct = 1
    for i in range(rows_data):
        for j in range(columns_data):
            font = cv2.FONT_HERSHEY_COMPLEX  #press tab for different operations
            img = np.dstack((data[i][j], data[i][j], data[i][j]))
            img = cv2.resize(img, (64, 64))
            cv2.putText(img, str(ct), (3,15), font, 0.5, (0,255,0), 1, cv2.LINE_AA)
            axarr[i, j].imshow(img, cmap="gray")
            axarr[i, j].axis("off")
            ct+=1
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()


#  Creating frames from videos
def frames_extraction(video_path):
    frames_list = []
     
    vidObj = cv2.VideoCapture(video_path)
    # Used as counter variable 
    count = 1
    while count <= seq_len: 
        success, image = vidObj.read() 
        if success:
            image = cv2.resize(image, (img_height, img_width))
            # Convert to grayscale
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            frames_list.append(image)
            count += 1
        else:
            print("Defected frame")
            break
    return frames_list
 
def create_data(input_dir):
    X = []
    Y = []
     
    classes_list = classes # or use os.listdir(input_dir)
     
    for c in classes_list:
        print(c)
        files_list = os.listdir(os.path.join(input_dir, c))
        for f in files_list:
            frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
            if len(frames) == seq_len:
                X.append(frames)
             
                y = [0]*len(classes)
                y[classes.index(c)] = 1
                Y.append(y)
     
    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y

# %%
# Create numpy array of data, this was done locally
# X, Y = create_data(data_dir)
# print(X.shape, Y.shape)

# np.save("{}/x.npy".format(DATASET_PATH), X)
# np.save("{}/y.npy".format(DATASET_PATH), Y)

# %%
X = np.load("{}/ucf10_videos.npy".format(DATASET_PATH))
Y = np.load("{}/ucf10_labels.npy".format(DATASET_PATH))
X = np.expand_dims(X, axis=4)
print(X.shape, Y.shape)
# Out:
# (1366, 70, 224, 224, 1) (1366, 10)

# %%
seed = 0
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle=True, random_state=seed)
X, Y = None, None
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1092, 70, 224, 224, 1) (274, 70, 224, 224, 1) (1092, 10) (274, 10)

# %%
# Visualize montage of slices.
ct = 200
idx = np.argmax(y_train[ct])
print("Video of {}.".format(classes[idx]))
plot_slices(7, 10, 224, 224, 1, X_train[ct])
# Out:
# Video of JumpingJack.

# %% [markdown]
# ### Models

# %%
def convlstm():
  """Stupid model"""
  seq_len, img_height, img_width = 70, 64, 64
  model = tf.keras.Sequential()
  model.add(tf.keras.layers.ConvLSTM2D(filters = 64, kernel_size = (3, 3), return_sequences = False, data_format = "channels_last", input_shape = (seq_len, img_height, img_width, 1)))
  model.add(tf.keras.layers.Dropout(0.2))
  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.Dense(256, activation="relu"))
  model.add(tf.keras.layers.Dropout(0.3))
  model.add(tf.keras.layers.Dense(6, activation = "softmax"))
  # Compile model
  optimizer = tf.keras.optimizers.SGD(lr=0.001)
  model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=["accuracy"])
  return model


def vgg_lstm():
  """Somewhat better"""
  # define input D, W, H, 1
  video = tf.keras.layers.Input(shape=(seq_len,
                      img_height,
                      img_width,
                      1))
  
  # map N channels data to 3 channels for input to CNN
  layer_3d = tf.keras.layers.Conv3D(3, (1, 1, 1))(video) 
  # define base model for feature extraction
  cnn_base = tf.keras.applications.VGG16(input_shape=(img_height,
                                img_width,
                                3),
                  weights="imagenet",
                  include_top=False)
  cnn_out = tf.keras.layers.GlobalAveragePooling2D()(cnn_base.output)
  cnn = tf.keras.Model(inputs=cnn_base.input, outputs=cnn_out)
  cnn.trainable = False

  # video frames go through cnn and then to lstm
  encoded_frames = tf.keras.layers.TimeDistributed(cnn)(layer_3d)
  print(encoded_frames)
  encoded_sequence = tf.keras.layers.LSTM(256)(encoded_frames)
  hidden_layer = tf.keras.layers.Dense(1024, activation="relu")(encoded_sequence)
  outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(hidden_layer)
  model = tf.keras.Model([video], outputs)

  optimizer = tf.keras.optimizers.SGD(lr=0.001)
  # optimizer = tf.keras.optimizers.Nadam(lr=0.002,
  #                   beta_1=0.9,
  #                   beta_2=0.999,
  #                   epsilon=1e-08,
  #                   schedule_decay=0.004)
  model.compile(loss="categorical_crossentropy",
                optimizer=optimizer,
                metrics=["accuracy"])
  return model

def vgg_lstm_4096():
  """More better, maybe? Test it out.
  Try GRUs next.
  """
  # define input D, W, H, 1
  video = tf.keras.layers.Input(shape=(seq_len,
                      img_height,
                      img_width,
                      1))
  
  # map N channels data to 3 channels for input to CNN
  layer_3d = tf.keras.layers.Conv3D(3, (1, 1, 1))(video) 
  # define base model for feature extraction
  cnn_base = tf.keras.applications.VGG16(input_shape=(img_height,
                                img_width,
                                3),
                  weights="imagenet",
                  include_top=True) # set to True, when using 4096-d f.v
  cnn = tf.keras.Model(inputs=cnn_base.input, outputs=cnn_base.layers[-3].output)
  cnn.trainable = False
  
  # video frames go through cnn and then to lstm
  encoded_frames = tf.keras.layers.TimeDistributed(cnn)(layer_3d)
  print(encoded_frames)
  encoded_sequence = tf.keras.layers.LSTM(256)(encoded_frames)
  hidden_layer = tf.keras.layers.Dense(1024, activation="relu")(encoded_sequence)
  outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(hidden_layer)
  model = tf.keras.Model([video], outputs)
  optimizer = tf.keras.optimizers.Nadam(lr=0.002,
                    beta_1=0.9,
                    beta_2=0.999,
                    epsilon=1e-08,
                    schedule_decay=0.004)
  model.compile(loss="categorical_crossentropy",
                optimizer=optimizer,
                metrics=["accuracy"])
  return model

# %% [markdown]
# ### Compile and train

# %%
# Callbacks
earlystop = tf.keras.callbacks.EarlyStopping(patience=8,
                          verbose=1,
                          restore_best_weights=True)

reducelr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',
                                             factor=0.1, 
                                             verbose=1, 
                                             patience=5, 
                                             mode='max')

checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath="{}/{}.h5".format(LOG_PATH, CFG_NAME),
                                            monitor='val_accuracy',
                                            mode='max',
                                            verbose=1,
                                            save_best_only=True)

callbacks = [earlystop, reducelr, checkpoint]

# Create model
model = None
model = vgg_lstm()
print(model.summary())
tf.keras.utils.plot_model(model, to_file='{}/model_plot.png'.format(LOG_PATH), show_shapes=True, show_layer_names=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# KerasTensor(type_spec=TensorSpec(shape=(None, 70, 512), dtype=tf.float32, name=None), name='time_distributed/Reshape_1:0', description="created by layer 'time_distributed'")
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 70, 224, 224, 1)] 0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 70, 224, 224, 3)   6
# _________________________________________________________________
# time_distributed (TimeDistri (None, 70, 512)           14714688
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               787456
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 15,775,568
# Trainable params: 1,060,880
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
# Train
print("Training model.")
history = model.fit(x = X_train, y = y_train, 
                    callbacks=callbacks,
                    epochs=100, 
                    batch_size = 1, 
                    shuffle=True, 
                    validation_split=0.2 
                    )
plot_loss_accu(history)
# Out:
# Training model.
# Epoch 1/100
# 873/873 [==============================] - 321s 325ms/step - loss: 2.0508 - accuracy: 0.3341 - val_loss: 1.5855 - val_accuracy: 0.6667
#
# Epoch 00001: val_accuracy improved from -inf to 0.66667, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 2/100
# 873/873 [==============================] - 283s 324ms/step - loss: 1.3402 - accuracy: 0.7111 - val_loss: 1.0836 - val_accuracy: 0.7397
#
# Epoch 00002: val_accuracy improved from 0.66667 to 0.73973, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 3/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.9497 - accuracy: 0.7907 - val_loss: 0.8751 - val_accuracy: 0.7854
#
# Epoch 00003: val_accuracy improved from 0.73973 to 0.78539, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 4/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.6955 - accuracy: 0.8397 - val_loss: 0.7361 - val_accuracy: 0.7991
#
# Epoch 00004: val_accuracy improved from 0.78539 to 0.79909, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 5/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.5791 - accuracy: 0.8609 - val_loss: 0.5956 - val_accuracy: 0.8447
#
# Epoch 00005: val_accuracy improved from 0.79909 to 0.84475, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 6/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.4198 - accuracy: 0.9237 - val_loss: 0.5482 - val_accuracy: 0.8539
#
# Epoch 00006: val_accuracy improved from 0.84475 to 0.85388, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 7/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.3271 - accuracy: 0.9451 - val_loss: 0.4182 - val_accuracy: 0.8904
#
# Epoch 00007: val_accuracy improved from 0.85388 to 0.89041, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 8/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.2561 - accuracy: 0.9568 - val_loss: 0.3413 - val_accuracy: 0.8904
#
# Epoch 00008: val_accuracy did not improve from 0.89041
# Epoch 9/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.1951 - accuracy: 0.9831 - val_loss: 0.3209 - val_accuracy: 0.9178
#
# Epoch 00009: val_accuracy improved from 0.89041 to 0.91781, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 10/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.1577 - accuracy: 0.9860 - val_loss: 0.3130 - val_accuracy: 0.8950
#
# Epoch 00010: val_accuracy did not improve from 0.91781
# Epoch 11/100
# 873/873 [==============================] - 282s 323ms/step - loss: 0.1255 - accuracy: 0.9935 - val_loss: 0.2997 - val_accuracy: 0.9178
#
# Epoch 00011: val_accuracy did not improve from 0.91781
# Epoch 12/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.0894 - accuracy: 0.9997 - val_loss: 0.2709 - val_accuracy: 0.9087
#
# Epoch 00012: val_accuracy did not improve from 0.91781
# Epoch 13/100
# 873/873 [==============================] - 282s 323ms/step - loss: 0.0795 - accuracy: 0.9949 - val_loss: 0.2764 - val_accuracy: 0.9224
#
# Epoch 00013: val_accuracy improved from 0.91781 to 0.92237, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 14/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.0674 - accuracy: 0.9979 - val_loss: 0.2468 - val_accuracy: 0.9132
#
# Epoch 00014: val_accuracy did not improve from 0.92237
# Epoch 15/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.2414 - val_accuracy: 0.9269
#
# Epoch 00015: val_accuracy improved from 0.92237 to 0.92694, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 16/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9315
#
# Epoch 00016: val_accuracy improved from 0.92694 to 0.93151, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 17/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9361
#
# Epoch 00017: val_accuracy improved from 0.93151 to 0.93607, saving model to /content/gdrive/My Drive/deeplearning/tbt-classification/logs/vgg_lstm_10_sgd_tf24/vgg_lstm_10_sgd_tf24.h5
# Epoch 18/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9361
#
# Epoch 00018: val_accuracy did not improve from 0.93607
# Epoch 19/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9315
#
# Epoch 00019: val_accuracy did not improve from 0.93607
# Epoch 20/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9315
#
# Epoch 00020: val_accuracy did not improve from 0.93607
# Epoch 21/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9269
#
# Epoch 00021: val_accuracy did not improve from 0.93607
# Epoch 22/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9269
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00022: val_accuracy did not improve from 0.93607
# Epoch 23/100
# 873/873 [==============================] - 282s 323ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.1913 - val_accuracy: 0.9315
#
# Epoch 00023: val_accuracy did not improve from 0.93607
# Epoch 24/100
# 873/873 [==============================] - 282s 323ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.1918 - val_accuracy: 0.9315
#
# Epoch 00024: val_accuracy did not improve from 0.93607
# Epoch 25/100
# 873/873 [==============================] - 282s 323ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1930 - val_accuracy: 0.9315
#
# Epoch 00025: val_accuracy did not improve from 0.93607
# Epoch 26/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9315
#
# Epoch 00026: val_accuracy did not improve from 0.93607
# Epoch 27/100
# 873/873 [==============================] - 282s 323ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9315
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00027: val_accuracy did not improve from 0.93607
# Epoch 28/100
# 873/873 [==============================] - 282s 323ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9315
#
# Epoch 00028: val_accuracy did not improve from 0.93607
# Epoch 29/100
# 873/873 [==============================] - 282s 324ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9315
#
# Epoch 00029: val_accuracy did not improve from 0.93607
# Epoch 30/100
# 873/873 [==============================] - 283s 324ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9315
# Restoring model weights from the end of the best epoch.
#
# Epoch 00030: val_accuracy did not improve from 0.93607
# Epoch 00030: early stopping

# %% [markdown]
# ### Test

# %%
from tensorflow.keras.models import load_model

model = None
model = load_model("{}/{}.h5".format(LOG_PATH, CFG_NAME), compile = False)
model.summary()

# Run prediction
y_pred = []
print("Running predictions on test set.")
for x in X_test:
  y_pred.append(model.predict(np.expand_dims(x, axis=0)))
y_pred = np.array(y_pred)
y_pred = np.squeeze(y_pred)

# Flatten
y_pred = np.argmax(y_pred, axis = 1)
y_test = np.argmax(y_test, axis = 1)
assert y_pred.shape == y_test.shape, "Should be same!"
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 70, 224, 224, 1)] 0
# _________________________________________________________________
# conv3d (Conv3D)              (None, 70, 224, 224, 3)   6
# _________________________________________________________________
# time_distributed (TimeDistri (None, 70, 512)           14714688
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               787456
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 15,775,568
# Trainable params: 1,060,880
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Running predictions on test set.

# %%
# %%capture cap --no-stderr
compute_accuray_kappa_score(y_test, y_pred)
print("\n")
print(classification_report(y_test, y_pred))

# %%
with open('{}/test_results.txt'.format(LOG_PATH), 'w') as f:
    f.write(cap.stdout)

# %%
print("Done!")
# Out:
# Done!
